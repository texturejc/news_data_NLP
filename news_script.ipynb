# %%
import pandas as pd

# %%
import seaborn as sns
sns.set()

# %%
small = pd.read_pickle("/content/small_news_data.pkl")
days = pd.read_pickle("/content/processed_news_grouped_by_day.pkl")

# %%
small['headline'] = [i.lower() for i in small['headline']]

# %%
days = pd.read_pickle("/content/processed_news_grouped_by_day.pkl")

# %%
small
# Out:
#                            date  \
# 0           2015-05-26 00:00:00
# 1           2015-05-28 00:00:00
# 2           2016-04-29 00:00:00
# 3           2018-11-27 00:00:00
# 4           2017-11-16 00:00:00
# ...                         ...
# 9995        2018-09-12 00:00:00
# 9996        2018-10-01 00:00:00
# 9997  2017-12-08 18:58:47+00:00
# 9998        2018-11-25 00:00:00
# 9999        2020-03-08 00:00:00
#
#                                                headline      source  \
# 0     gareth bale is being overlooked by his real ma...  Daily Mail
# 1              no sign of early federal election at aec  Daily Mail
# 2     'lethal escalation' in syria being readied  - ...  Daily Mail
# 3     rita ora is every inch the angelic tot in swee...  Daily Mail
# 4     royal mail warns union talks could hit perform...  Daily Mail
# ...                                                 ...         ...
# 9995  suki waterhouse is stylish in silky pink pants...  Daily Mail
# ...

# %%
small
# Out:
#                            date  \
# 0           2015-05-26 00:00:00
# 1           2015-05-28 00:00:00
# 2           2016-04-29 00:00:00
# 3           2018-11-27 00:00:00
# 4           2017-11-16 00:00:00
# ...                         ...
# 9995        2018-09-12 00:00:00
# 9996        2018-10-01 00:00:00
# 9997  2017-12-08 18:58:47+00:00
# 9998        2018-11-25 00:00:00
# 9999        2020-03-08 00:00:00
#
#                                                headline      source  \
# 0     Gareth Bale is being overlooked by his Real Ma...  Daily Mail
# 1              No sign of early federal election at AEC  Daily Mail
# 2     'Lethal escalation' in Syria being readied  - ...  Daily Mail
# 3     Rita Ora is every inch the angelic tot in swee...  Daily Mail
# 4     Royal Mail warns union talks could hit perform...  Daily Mail
# ...                                                 ...         ...
# 9995  Suki Waterhouse is stylish in silky pink pants...  Daily Mail
# ...

# %%
keyword = 'Brexit'
df = small[small['headline'].str.contains(keyword, na=False)]

# %%
df
# Out:
#                            date  \
# 48          2017-09-02 00:00:00
# 70    2018-01-07 12:36:06+00:00
# 369         2019-10-09 00:00:00
# 446         2018-07-31 00:00:00
# 576         2019-09-03 00:00:00
# ...                         ...
# 9700        2017-11-23 00:00:00
# 9767        2016-05-17 00:00:00
# 9807        2017-10-13 00:00:00
# 9925        2016-11-24 00:00:00
# 9935        2017-01-09 00:00:00
#
#                                                headline      source   section  \
# 48      Labour has no intention of taking back contr...     Express   comment
# 70    Farage to claim to be voice of 17.4m Brexit vo...    Guardian  politics
# 369   British PM Johnson "still cautiously optimisti...  Daily Mail     wires
# 446   Banks say UK finance exports underscore need f...  Daily Mail     wires
# 576   FTSE CLOSE: Pound slides under $1.20 as MPs tr...  Daily Mail     money
# ...                                                 ...         ...       ...
# ...
